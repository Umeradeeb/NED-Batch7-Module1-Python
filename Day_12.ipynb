# %%
import pandas as pd
import numpy as np

# %%
#generating sample google play store data
data = {
    'App': [f'App_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Game', 'Productivity', 'Health', 'Education'],30),
    'Rating': np.random.uniform(1.0, 5.0, 30).round(1),
    'Reviews': np.random.randint(1, 10000, 30),
    'Size': np.random.choice(['Varies with device', '10M', '20M', '30M'], 30),
    'Installs': np.random.choice(['1,000+', '10,000+', '50,000+', '100,000+'], 30),
    'Type': np.random.choice(['Free', 'Paid'], 30),
    'Price': np.random.choice(['0', '0.99', '1.99', '2.99', '4.99', '5.99', '9.99'], 30),
    'Content Rating': np.random.choice(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], 30)
}

# %%
data
# Out:
# {'App': ['App_1',
#   'App_2',
#   'App_3',
#   'App_4',
#   'App_5',
#   'App_6',
#   'App_7',
#   'App_8',
#   'App_9',
#   'App_10',
#   'App_11',
#   'App_12',
#   'App_13',
#   'App_14',
#   'App_15',
#   'App_16',
#   'App_17',
#   'App_18',
#   'App_19',
#   'App_20',
#   'App_21',
#   'App_22',
#   'App_23',
#   'App_24',
#   'App_25',
#   'App_26',
#   'App_27',
#   'App_28',
#   'App_29',
#   'App_30'],
#  'Category': array(['Health', 'Health', 'Education', 'Health', 'Health',
#         'Productivity', 'Productivity', 'Game', 'Health', 'Productivity',
#         'Game', 'Productivity', 'Education', 'Productivity', 'Education',
#         'Productivity', 'Productivity', 'Health', 'Education', 'Education',
#         'Game', 'Health', 'Productivity', 'Game', 'Game', 'Game',
#         'Productivity', 'Health', 'Productivity', 'Education'],
#        dtype='<U12'),
#  'Rating': array([3.1, 1.9, 3. , 2.4, 1.8, 3.9, 2.5, 1.1, 1.9, 2.9, 3.5, 3.4, 3.8,
# ...

# %%
type(data)
# Out:
# dict

# %% [markdown]
# # ***different libraries offer deifferent functions***
#
# ***pandas*** (data handling or manipulation),
# ***numpy*** (numerical calculation, some data manipulation functions also available),
# ***matplotlib***

# %%
#creating data frame
df = pd.DataFrame(data)

# %%
df
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 0    App_1        Health     3.1     7125                 20M   50,000+  Free
# 1    App_2        Health     1.9     9118  Varies with device  100,000+  Free
# 2    App_3     Education     3.0      755                 30M  100,000+  Free
# 3    App_4        Health     2.4     1327  Varies with device  100,000+  Free
# 4    App_5        Health     1.8     9823                 10M  100,000+  Paid
# 5    App_6  Productivity     3.9     6526  Varies with device    1,000+  Free
# 6    App_7  Productivity     2.5     6197                 10M    1,000+  Paid
# 7    App_8          Game     1.1     7784                 20M  100,000+  Paid
# 8    App_9        Health     1.9     8718  Varies with device  100,000+  Paid
# 9   App_10  Productivity     2.9     9855  Varies with device   10,000+  Paid
# 10  App_11          Game     3.5     8603                 10M  100,000+  Paid
# ...

# %%
df.head()
# Out:
#      App   Category  Rating  Reviews                Size  Installs  Type  \
# 0  App_1     Health     3.1     7125                 20M   50,000+  Free
# 1  App_2     Health     1.9     9118  Varies with device  100,000+  Free
# 2  App_3  Education     3.0      755                 30M  100,000+  Free
# 3  App_4     Health     2.4     1327  Varies with device  100,000+  Free
# 4  App_5     Health     1.8     9823                 10M  100,000+  Paid
#
#   Price Content Rating
# 0  2.99       Everyone
# 1  2.99   Everyone 10+
# 2  1.99   Everyone 10+
# 3  9.99       Everyone
# 4  0.99     Mature 17+

# %%
df.tail()
# Out:
#        App      Category  Rating  Reviews                Size Installs  Type  \
# 25  App_26          Game     4.1     8735                 20M  50,000+  Free
# 26  App_27  Productivity     4.3     4241                 30M  50,000+  Free
# 27  App_28        Health     2.7     3167  Varies with device  50,000+  Paid
# 28  App_29  Productivity     5.0      406                 30M  50,000+  Paid
# 29  App_30     Education     2.2     2656  Varies with device  10,000+  Paid
#
#    Price Content Rating
# 25  1.99       Everyone
# 26     0       Everyone
# 27  5.99     Mature 17+
# 28  4.99     Mature 17+
# 29  4.99   Everyone 10+

# %%
df.tail(2)
# Out:
#        App      Category  Rating  Reviews                Size Installs  Type  \
# 28  App_29  Productivity     5.0      406                 30M  50,000+  Paid
# 29  App_30     Education     2.2     2656  Varies with device  10,000+  Paid
#
#    Price Content Rating
# 28  4.99     Mature 17+
# 29  4.99   Everyone 10+

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int32
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     object
#  8   Content Rating  30 non-null     object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 2.1+ KB

# %%
# in data frame string is called object

# %%
df['App']
# Out:
# 0      App_1
# 1      App_2
# 2      App_3
# 3      App_4
# 4      App_5
# 5      App_6
# 6      App_7
# 7      App_8
# 8      App_9
# 9     App_10
# 10    App_11
# 11    App_12
# 12    App_13
# 13    App_14
# 14    App_15
# 15    App_16
# 16    App_17
# 17    App_18
# 18    App_19
# 19    App_20
# 20    App_21
# 21    App_22
# 22    App_23
# 23    App_24
# 24    App_25
# 25    App_26
# 26    App_27
# 27    App_28
# 28    App_29
# 29    App_30
# Name: App, dtype: object

# %%
df['App'].replace('App_1','Facebook')
# Out:
# 0     Facebook
# 1        App_2
# 2        App_3
# 3        App_4
# 4        App_5
# 5        App_6
# 6        App_7
# 7        App_8
# 8        App_9
# 9       App_10
# 10      App_11
# 11      App_12
# 12      App_13
# 13      App_14
# 14      App_15
# 15      App_16
# 16      App_17
# 17      App_18
# 18      App_19
# 19      App_20
# 20      App_21
# 21      App_22
# 22      App_23
# 23      App_24
# 24      App_25
# 25      App_26
# 26      App_27
# 27      App_28
# 28      App_29
# 29      App_30
# Name: App, dtype: object

# %%
apps_list = [
    "WhatsApp Messenger",
    "Instagram",
    "Facebook",
    "YouTube",
    "Snapchat",
    "TikTok",
    "Twitter",
    "Spotify",
    "Netflix",
    "Google Chrome",
    "Gmail",
    "Google Maps",
    "Uber",
    "Lyft",
    "Airbnb",
    "Amazon Shopping",
    "Microsoft Office",
    "Adobe Acrobat Reader",
    "WhatsApp Business",
    "Messenger (by Facebook)",
    "Pinterest",
    "LinkedIn",
    "Zoom",
    "Discord",
    "Shazam",
    "Duolingo",
    "Google Drive",
    "Dropbox",
    "Microsoft Teams",
    "Slack"
]

# %%
#data fram name ['column name'] = list name
df['App'] = apps_list

# %%
df['App']
# Out:
# 0          WhatsApp Messenger
# 1                   Instagram
# 2                    Facebook
# 3                     YouTube
# 4                    Snapchat
# 5                      TikTok
# 6                     Twitter
# 7                     Spotify
# 8                     Netflix
# 9               Google Chrome
# 10                      Gmail
# 11                Google Maps
# 12                       Uber
# 13                       Lyft
# 14                     Airbnb
# 15            Amazon Shopping
# 16           Microsoft Office
# 17       Adobe Acrobat Reader
# 18          WhatsApp Business
# 19    Messenger (by Facebook)
# 20                  Pinterest
# 21                   LinkedIn
# 22                       Zoom
# 23                    Discord
# 24                     Shazam
# 25                   Duolingo
# 26               Google Drive
# 27                    Dropbox
# 28            Microsoft Teams
# 29                      Slack
# Name: App, dtype: object

# %%
df
# Out:
#                         App      Category  Rating  Reviews  \
# 0        WhatsApp Messenger        Health     3.1     7125
# 1                 Instagram        Health     1.9     9118
# 2                  Facebook     Education     3.0      755
# 3                   YouTube        Health     2.4     1327
# 4                  Snapchat        Health     1.8     9823
# 5                    TikTok  Productivity     3.9     6526
# 6                   Twitter  Productivity     2.5     6197
# 7                   Spotify          Game     1.1     7784
# 8                   Netflix        Health     1.9     8718
# 9             Google Chrome  Productivity     2.9     9855
# 10                    Gmail          Game     3.5     8603
# 11              Google Maps  Productivity     3.4     1675
# 12                     Uber     Education     3.8     9622
# 13                     Lyft  Productivity     3.6     8022
# 14                   Airbnb     Education     1.6      602
# ...

# %%
for i in df['Content Rating']:
    print (i)
# Out:
# Everyone
# Everyone 10+
# Everyone 10+
# Everyone
# Mature 17+
# Mature 17+
# Teen
# Teen
# Teen
# Teen
# Everyone 10+
# Mature 17+
# Everyone 10+
# Everyone 10+
# Teen
# Mature 17+
# Everyone 10+
# Everyone
# Everyone 10+
# Teen
# Everyone 10+
# Everyone 10+
# Mature 17+
# Everyone 10+
# Mature 17+
# Everyone
# Everyone
# Mature 17+
# Mature 17+
# Everyone 10+

# %%
df['Content Rating'].replace('Mature 17+','Mature 18+')
# Out:
# 0         Everyone
# 1     Everyone 10+
# 2     Everyone 10+
# 3         Everyone
# 4       Mature 18+
# 5       Mature 18+
# 6             Teen
# 7             Teen
# 8             Teen
# 9             Teen
# 10    Everyone 10+
# 11      Mature 18+
# 12    Everyone 10+
# 13    Everyone 10+
# 14            Teen
# 15      Mature 18+
# 16    Everyone 10+
# 17        Everyone
# 18    Everyone 10+
# 19            Teen
# 20    Everyone 10+
# 21    Everyone 10+
# 22      Mature 18+
# 23    Everyone 10+
# 24      Mature 18+
# 25        Everyone
# 26        Everyone
# 27      Mature 18+
# 28      Mature 18+
# 29    Everyone 10+
# Name: Content Rating, dtype: object

# %%
df['Rating'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20     True
# 21     True
# 22     True
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29     True
# Name: Rating, dtype: bool

# %%
df['Rating'].duplicated().sum()
# Out:
# 7

# %%
df = df.drop_duplicates(subset=['Rating'])

# %%
df
# Out:
#                         App      Category  Rating  Reviews  \
# 0        WhatsApp Messenger        Health     3.1     7125
# 1                 Instagram        Health     1.9     9118
# 2                  Facebook     Education     3.0      755
# 3                   YouTube        Health     2.4     1327
# 4                  Snapchat        Health     1.8     9823
# 5                    TikTok  Productivity     3.9     6526
# 6                   Twitter  Productivity     2.5     6197
# 7                   Spotify          Game     1.1     7784
# 9             Google Chrome  Productivity     2.9     9855
# 10                    Gmail          Game     3.5     8603
# 11              Google Maps  Productivity     3.4     1675
# 12                     Uber     Education     3.8     9622
# 13                     Lyft  Productivity     3.6     8022
# 14                   Airbnb     Education     1.6      602
# 15          Amazon Shopping  Productivity     3.7     7487
# ...

# %%
df['Rating'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 19    False
# 23    False
# 24    False
# 25    False
# 26    False
# 28    False
# Name: Rating, dtype: bool

# %%
df['Rating'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 19    False
# 23    False
# 24    False
# 25    False
# 26    False
# 28    False
# Name: Rating, dtype: bool

# %%
df['Rating'].isnull().sum()
# Out:
# 0

# %%
df['Rating'].mean()
# Out:
# 3.1347826086956525

# %%
#filling null values in data frame with mean
df['Rating'] = df['Rating'].fillna(df['Rating'].mean())
# Out:
# C:\Users\MAK TECH\AppData\Local\Temp\ipykernel_7924\3484394557.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating'] = df['Rating'].fillna(df['Rating'].mean())

# %%
df['Reviews']
# Out:
# 0     7125
# 1     9118
# 2      755
# 3     1327
# 4     9823
# 5     6526
# 6     6197
# 7     7784
# 9     9855
# 10    8603
# 11    1675
# 12    9622
# 13    8022
# 14     602
# 15    7487
# 16    1297
# 17     652
# 19    7691
# 23    1056
# 24    9235
# 25    8735
# 26    4241
# 28     406
# Name: Reviews, dtype: int32

# %%
df['Reviews'] = (df['Reviews'] - df['Reviews'].min()) / (df['Reviews'].max() - df['Reviews'].min())
# Out:
# C:\Users\MAK TECH\AppData\Local\Temp\ipykernel_7924\10106146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Reviews'] = (df['Reviews'] - df['Reviews'].min()) / (df['Reviews'].max() - df['Reviews'].min())

# %%
df['Reviews']
# Out:
# 0     0.711081
# 1     0.922002
# 2     0.036935
# 3     0.097471
# 4     0.996613
# 5     0.647688
# 6     0.612869
# 7     0.780823
# 9     1.000000
# 10    0.867499
# 11    0.134300
# 12    0.975341
# 13    0.806011
# 14    0.020743
# 15    0.749391
# 16    0.094296
# 17    0.026035
# 19    0.770981
# 23    0.068790
# 24    0.934385
# 25    0.881469
# 26    0.405863
# 28    0.000000
# Name: Reviews, dtype: float64

# %%
df['Size']
# Out:
# 0                    20M
# 1     Varies with device
# 2                    30M
# 3     Varies with device
# 4                    10M
# 5     Varies with device
# 6                    10M
# 7                    20M
# 9     Varies with device
# 10                   10M
# 11                   30M
# 12                   20M
# 13                   10M
# 14                   10M
# 15                   10M
# 16                   10M
# 17                   10M
# 19                   30M
# 23                   10M
# 24                   10M
# 25                   20M
# 26                   30M
# 28                   30M
# Name: Size, dtype: object

# %%
df['Size'] = df['Size'].replace('Varies with device', np.nan)
# Out:
# C:\Users\MAK TECH\AppData\Local\Temp\ipykernel_7924\3209142163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size'] = df['Size'].replace('Varies with device', np.nan)

# %%
pd.options.mode.copy_on_write = True

# %%
df['Size']
# Out:
# 0     20M
# 1     NaN
# 2     30M
# 3     NaN
# 4     10M
# 5     NaN
# 6     10M
# 7     20M
# 9     NaN
# 10    10M
# 11    30M
# 12    20M
# 13    10M
# 14    10M
# 15    10M
# 16    10M
# 17    10M
# 19    30M
# 23    10M
# 24    10M
# 25    20M
# 26    30M
# 28    30M
# Name: Size, dtype: object

# %%
df['Size'] = df['Size'].str.replace('M', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df['Size'] = df['Size'].str.replace('M', '').astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df['Size']
# Out:
# 0     20.0
# 1      NaN
# 2     30.0
# 3      NaN
# 4     10.0
# 5      NaN
# 6     10.0
# 7     20.0
# 9      NaN
# 10    10.0
# 11    30.0
# 12    20.0
# 13    10.0
# 14    10.0
# 15    10.0
# 16    10.0
# 17    10.0
# 19    30.0
# 23    10.0
# 24    10.0
# 25    20.0
# 26    30.0
# 28    30.0
# Name: Size, dtype: float64

# %%
df['Size'] = df['Size'].fillna(df['Size'].mean())

# %%
df['Size']
# Out:
# 0     20.000000
# 1     17.368421
# 2     30.000000
# 3     17.368421
# 4     10.000000
# 5     17.368421
# 6     10.000000
# 7     20.000000
# 9     17.368421
# 10    10.000000
# 11    30.000000
# 12    20.000000
# 13    10.000000
# 14    10.000000
# 15    10.000000
# 16    10.000000
# 17    10.000000
# 19    30.000000
# 23    10.000000
# 24    10.000000
# 25    20.000000
# 26    30.000000
# 28    30.000000
# Name: Size, dtype: float64

# %%
df['Size'] = df['Size'].replace(21.176471, np.nan)

# %%
df['Size']
# Out:
# 0     20.000000
# 1     17.368421
# 2     30.000000
# 3     17.368421
# 4     10.000000
# 5     17.368421
# 6     10.000000
# 7     20.000000
# 9     17.368421
# 10    10.000000
# 11    30.000000
# 12    20.000000
# 13    10.000000
# 14    10.000000
# 15    10.000000
# 16    10.000000
# 17    10.000000
# 19    30.000000
# 23    10.000000
# 24    10.000000
# 25    20.000000
# 26    30.000000
# 28    30.000000
# Name: Size, dtype: float64

# %%
df[['Type','Price']]
# Out:
#     Type Price
# 0   Free  2.99
# 1   Free  2.99
# 2   Free  1.99
# 3   Free  9.99
# 4   Paid  0.99
# 5   Free  4.99
# 6   Paid  0.99
# 7   Paid  1.99
# 9   Paid     0
# 10  Paid  2.99
# 11  Free  2.99
# 12  Paid  2.99
# 13  Paid  2.99
# 14  Paid  0.99
# 15  Free  1.99
# 16  Paid     0
# 17  Free  9.99
# 19  Paid  9.99
# 23  Free     0
# 24  Free  9.99
# 25  Free  1.99
# 26  Free     0
# 28  Paid  4.99

# %%
df['Price'] = df['Price'].astype(float)

# %%
df['Affordable'] = np.where(df['Type'] == 'Paid', np.where(df['Price'] < 5.00, 'Yes', 'No'), 'N/A')

# %%
df
# Out:
#                         App      Category  Rating   Reviews       Size  \
# 0        WhatsApp Messenger        Health     3.1  0.711081  20.000000
# 1                 Instagram        Health     1.9  0.922002  17.368421
# 2                  Facebook     Education     3.0  0.036935  30.000000
# 3                   YouTube        Health     2.4  0.097471  17.368421
# 4                  Snapchat        Health     1.8  0.996613  10.000000
# 5                    TikTok  Productivity     3.9  0.647688  17.368421
# 6                   Twitter  Productivity     2.5  0.612869  10.000000
# 7                   Spotify          Game     1.1  0.780823  20.000000
# 9             Google Chrome  Productivity     2.9  1.000000  17.368421
# 10                    Gmail          Game     3.5  0.867499  10.000000
# 11              Google Maps  Productivity     3.4  0.134300  30.000000
# 12                     Uber     Education     3.8  0.975341  20.000000
# ...

# %%
df[df['Type'] == 'Paid']
# Out:
#                         App      Category  Rating   Reviews       Size  \
# 4                  Snapchat        Health     1.8  0.996613  10.000000
# 6                   Twitter  Productivity     2.5  0.612869  10.000000
# 7                   Spotify          Game     1.1  0.780823  20.000000
# 9             Google Chrome  Productivity     2.9  1.000000  17.368421
# 10                    Gmail          Game     3.5  0.867499  10.000000
# 12                     Uber     Education     3.8  0.975341  20.000000
# 13                     Lyft  Productivity     3.6  0.806011  10.000000
# 14                   Airbnb     Education     1.6  0.020743  10.000000
# 16         Microsoft Office  Productivity     2.1  0.094296  10.000000
# 19  Messenger (by Facebook)     Education     2.2  0.770981  30.000000
# 28          Microsoft Teams  Productivity     5.0  0.000000  30.000000
#
#     Installs  Type  Price Content Rating Affordable
# 4   100,000+  Paid   0.99     Mature 17+        Yes
# ...

# %%
df_paid = df[df['Type'] == 'Paid']

# %%
df_paid
# Out:
#                         App      Category  Rating   Reviews       Size  \
# 4                  Snapchat        Health     1.8  0.996613  10.000000
# 6                   Twitter  Productivity     2.5  0.612869  10.000000
# 7                   Spotify          Game     1.1  0.780823  20.000000
# 9             Google Chrome  Productivity     2.9  1.000000  17.368421
# 10                    Gmail          Game     3.5  0.867499  10.000000
# 12                     Uber     Education     3.8  0.975341  20.000000
# 13                     Lyft  Productivity     3.6  0.806011  10.000000
# 14                   Airbnb     Education     1.6  0.020743  10.000000
# 16         Microsoft Office  Productivity     2.1  0.094296  10.000000
# 19  Messenger (by Facebook)     Education     2.2  0.770981  30.000000
# 28          Microsoft Teams  Productivity     5.0  0.000000  30.000000
#
#     Installs  Type  Price Content Rating Affordable
# 4   100,000+  Paid   0.99     Mature 17+        Yes
# ...

# %%
df['Popularity'] = df['Rating'] * df['Reviews']

# %%
df.head()
# Out:
#                   App   Category  Rating   Reviews       Size  Installs  Type  \
# 0  WhatsApp Messenger     Health     3.1  0.711081  20.000000   50,000+  Free
# 1           Instagram     Health     1.9  0.922002  17.368421  100,000+  Free
# 2            Facebook  Education     3.0  0.036935  30.000000  100,000+  Free
# 3             YouTube     Health     2.4  0.097471  17.368421  100,000+  Free
# 4            Snapchat     Health     1.8  0.996613  10.000000  100,000+  Paid
#
#    Price Content Rating Affordable  Popularity
# 0   2.99       Everyone        N/A    2.204350
# 1   2.99   Everyone 10+        N/A    1.751804
# 2   1.99   Everyone 10+        N/A    0.110805
# 3   9.99       Everyone        N/A    0.233930
# 4   0.99     Mature 17+        Yes    1.793904

# %%
df.sort_values(['Popularity'])
# Out:
#                         App      Category  Rating   Reviews       Size  \
# 28          Microsoft Teams  Productivity     5.0  0.000000  30.000000
# 14                   Airbnb     Education     1.6  0.020743  10.000000
# 2                  Facebook     Education     3.0  0.036935  30.000000
# 17     Adobe Acrobat Reader        Health     4.8  0.026035  10.000000
# 23                  Discord          Game     2.7  0.068790  10.000000
# 16         Microsoft Office  Productivity     2.1  0.094296  10.000000
# 3                   YouTube        Health     2.4  0.097471  17.368421
# 11              Google Maps  Productivity     3.4  0.134300  30.000000
# 7                   Spotify          Game     1.1  0.780823  20.000000
# 6                   Twitter  Productivity     2.5  0.612869  10.000000
# 19  Messenger (by Facebook)     Education     2.2  0.770981  30.000000
# 26             Google Drive  Productivity     4.3  0.405863  30.000000
# ...

# %%
df.sort_values(['Popularity']).tail()
# Out:
#          App      Category  Rating   Reviews  Size  Installs  Type  Price  \
# 13      Lyft  Productivity     3.6  0.806011  10.0   50,000+  Paid   2.99
# 10     Gmail          Game     3.5  0.867499  10.0  100,000+  Paid   2.99
# 25  Duolingo          Game     4.1  0.881469  20.0   50,000+  Free   1.99
# 12      Uber     Education     3.8  0.975341  20.0  100,000+  Paid   2.99
# 24    Shazam          Game     4.7  0.934385  10.0   10,000+  Free   9.99
#
#    Content Rating Affordable  Popularity
# 13   Everyone 10+        Yes    2.901640
# 10   Everyone 10+        Yes    3.036247
# 25       Everyone        N/A    3.614023
# 12   Everyone 10+        Yes    3.706297
# 24     Mature 17+        N/A    4.391608

# %%
df.sort_values(['Popularity']).max()
# Out:
# App                    YouTube
# Category          Productivity
# Rating                     5.0
# Reviews                    1.0
# Size                      30.0
# Installs               50,000+
# Type                      Paid
# Price                     9.99
# Content Rating            Teen
# Affordable                 Yes
# Popularity            4.391608
# dtype: object

# %%
df.sort_values(by=['Popularity'], ascending = False)
# Out:
#                         App      Category  Rating   Reviews       Size  \
# 24                   Shazam          Game     4.7  0.934385  10.000000
# 12                     Uber     Education     3.8  0.975341  20.000000
# 25                 Duolingo          Game     4.1  0.881469  20.000000
# 10                    Gmail          Game     3.5  0.867499  10.000000
# 13                     Lyft  Productivity     3.6  0.806011  10.000000
# 9             Google Chrome  Productivity     2.9  1.000000  17.368421
# 15          Amazon Shopping  Productivity     3.7  0.749391  10.000000
# 5                    TikTok  Productivity     3.9  0.647688  17.368421
# 0        WhatsApp Messenger        Health     3.1  0.711081  20.000000
# 4                  Snapchat        Health     1.8  0.996613  10.000000
# 1                 Instagram        Health     1.9  0.922002  17.368421
# 26             Google Drive  Productivity     4.3  0.405863  30.000000
# ...

# %%
df[df['Type'] == 'Paid'].head()
# Out:
#               App      Category  Rating   Reviews       Size  Installs  Type  \
# 4        Snapchat        Health     1.8  0.996613  10.000000  100,000+  Paid
# 6         Twitter  Productivity     2.5  0.612869  10.000000    1,000+  Paid
# 7         Spotify          Game     1.1  0.780823  20.000000  100,000+  Paid
# 9   Google Chrome  Productivity     2.9  1.000000  17.368421   10,000+  Paid
# 10          Gmail          Game     3.5  0.867499  10.000000  100,000+  Paid
#
#     Price Content Rating Affordable  Popularity
# 4    0.99     Mature 17+        Yes    1.793904
# 6    0.99           Teen        Yes    1.532173
# 7    1.99           Teen        Yes    0.858906
# 9    0.00           Teen        Yes    2.900000
# 10   2.99   Everyone 10+        Yes    3.036247

# %%
df[df['Type'] == 'Free']
# Out:
#                      App      Category  Rating   Reviews       Size  Installs  \
# 0     WhatsApp Messenger        Health     3.1  0.711081  20.000000   50,000+
# 1              Instagram        Health     1.9  0.922002  17.368421  100,000+
# 2               Facebook     Education     3.0  0.036935  30.000000  100,000+
# 3                YouTube        Health     2.4  0.097471  17.368421  100,000+
# 5                 TikTok  Productivity     3.9  0.647688  17.368421    1,000+
# 11           Google Maps  Productivity     3.4  0.134300  30.000000   50,000+
# 15       Amazon Shopping  Productivity     3.7  0.749391  10.000000   10,000+
# 17  Adobe Acrobat Reader        Health     4.8  0.026035  10.000000   50,000+
# 23               Discord          Game     2.7  0.068790  10.000000  100,000+
# 24                Shazam          Game     4.7  0.934385  10.000000   10,000+
# 25              Duolingo          Game     4.1  0.881469  20.000000   50,000+
# ...

# %%
len(df[df['Type'] == 'Free'])
# Out:
# 12

# %%
len(df[df['Type'] == 'Paid'])
# Out:
# 11

# %%
df[df['App'] == 'Pinterest']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Affordable, Popularity]
# Index: []

# %%
df[(df['Type'] == 'Paid') & (df['Price'] < 2.00)]
# Out:
#                  App      Category  Rating   Reviews       Size  Installs  \
# 4           Snapchat        Health     1.8  0.996613  10.000000  100,000+
# 6            Twitter  Productivity     2.5  0.612869  10.000000    1,000+
# 7            Spotify          Game     1.1  0.780823  20.000000  100,000+
# 9      Google Chrome  Productivity     2.9  1.000000  17.368421   10,000+
# 14            Airbnb     Education     1.6  0.020743  10.000000   50,000+
# 16  Microsoft Office  Productivity     2.1  0.094296  10.000000  100,000+
#
#     Type  Price Content Rating Affordable  Popularity
# 4   Paid   0.99     Mature 17+        Yes    1.793904
# 6   Paid   0.99           Teen        Yes    1.532173
# 7   Paid   1.99           Teen        Yes    0.858906
# 9   Paid   0.00           Teen        Yes    2.900000
# 14  Paid   0.99           Teen        Yes    0.033189
# 16  Paid   0.00   Everyone 10+        Yes    0.198021

# %%
len(df[(df['Type'] == 'Paid') & (df['Price'] < 2.00)])
# Out:
# 6

# %%
df
# Out:
#                         App      Category  Rating   Reviews       Size  \
# 0        WhatsApp Messenger        Health     3.1  0.711081  20.000000
# 1                 Instagram        Health     1.9  0.922002  17.368421
# 2                  Facebook     Education     3.0  0.036935  30.000000
# 3                   YouTube        Health     2.4  0.097471  17.368421
# 4                  Snapchat        Health     1.8  0.996613  10.000000
# 5                    TikTok  Productivity     3.9  0.647688  17.368421
# 6                   Twitter  Productivity     2.5  0.612869  10.000000
# 7                   Spotify          Game     1.1  0.780823  20.000000
# 9             Google Chrome  Productivity     2.9  1.000000  17.368421
# 10                    Gmail          Game     3.5  0.867499  10.000000
# 11              Google Maps  Productivity     3.4  0.134300  30.000000
# 12                     Uber     Education     3.8  0.975341  20.000000
# ...

# %%
#df['Filter'] = np.where(df['Content Rating'] == 'Everyone 10+' , np.where(df['Size'] > 5.00), np.where(df['Popularity'] > 2.00 , 'Yes', 'No') , 'N/A')
#df['Affordable'] = np.where(df['Type'] == 'Paid', np.where(df['Price'] < 5.00, 'Yes', 'No'), 'N/A')

# %%
df['Filter'] = np.where(df['Content Rating'] == 'Everyone 10+', np.where(df['Size'] > 5.00, 'Yes', 'No'), np.where(df['Popularity'] > 2.00, 'Yes', 'No'))

# %%
df
# Out:
#                         App      Category  Rating   Reviews       Size  \
# 0        WhatsApp Messenger        Health     3.1  0.711081  20.000000
# 1                 Instagram        Health     1.9  0.922002  17.368421
# 2                  Facebook     Education     3.0  0.036935  30.000000
# 3                   YouTube        Health     2.4  0.097471  17.368421
# 4                  Snapchat        Health     1.8  0.996613  10.000000
# 5                    TikTok  Productivity     3.9  0.647688  17.368421
# 6                   Twitter  Productivity     2.5  0.612869  10.000000
# 7                   Spotify          Game     1.1  0.780823  20.000000
# 9             Google Chrome  Productivity     2.9  1.000000  17.368421
# 10                    Gmail          Game     3.5  0.867499  10.000000
# 11              Google Maps  Productivity     3.4  0.134300  30.000000
# 12                     Uber     Education     3.8  0.975341  20.000000
# ...

# %%
df.to_excel('PGD_Google_App_Data.xlsx')

# %%
df.to_csv("PGD_Google_App_Data")
